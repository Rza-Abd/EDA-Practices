# %% [markdown]
# <center><img src="./Bokking_image"/></center>

# %% [markdown]
# # Introduction
#
# The Hotel Booking Data Analysis presents a comprehensive exploration of a dataset capturing various aspects of hotel reservations. This dataset, a treasure trove of information, encompasses diverse dimensions such as booking patterns, guest demographics, and hotel performance. Through meticulous examination, this analysis aims to uncover valuable insights into the factors influencing hotel bookings and provide a deeper understanding of the trends shaping the hospitality industry.
#
# Hotel bookings are a critical aspect of the tourism and hospitality sector, reflecting the dynamic interplay of consumer preferences, economic conditions, and seasonal variations. By delving into this dataset, we seek to unravel patterns in guest behavior, discern peak booking periods, and identify the key determinants impacting reservation decisions. Additionally, we will explore the interrelationship between hotel characteristics, guest demographics, and booking cancellations.
#
# This analysis is poised to offer actionable insights for hotel managers, marketers, and policymakers alike. Understanding the nuances of booking data can inform strategic decisions, optimize resource allocation, and enhance the overall guest experience. As we embark on this exploration, we invite you to accompany us on a journey through the intricate tapestry of hotel bookings, unveiling the stories hidden within the numbers and illuminating the broader landscape of the hospitality industry.

# %% [markdown]
# # Column Descriptions
#
# ### **Hotel**
# * H1: Resort hotel
# * H2: City hotel
# ### **is_canceled**
# * 1: Canceled
# * 0: Not canceled
# ### **lead_time**
# * No of days thaat elapsed between entering date of booking into property management system and arrival date
# ### **arrival_date_year**
# * Year of arrival date (2015-2017)
# ### **arrival_date_month**
# * Month of arrival date (Jan - Dec)
# ### **arrival_date_week_numberr**
# * Week number of year for arrival date (1-53)
# ### **arrival_date_day_of_month**
# * Day of arrival date
# ### **stays_in_weekend_nights**
# * No of weekend nights (Sat/Sun) the guest stayed or booked to stay at the hotel
# ### **stays_in_week_nights**
# * No of week nights (Mon - Fri) the guest stayed or booked to stay at the hotel
# ### **Adults**
# ### **Children**
# ### **Babies**
# ### **meal**
# * Type of meal booked. Undefined/SC – no meal package; BB – Bed & Breakfast; HB – Half board (breakfast and one other meal – usually dinner); FB – Full board (breakfast, lunch and dinner)
# ### **country**
# ### **market_segment** (a group of people who share one or more common characteristics, lumped together for marketing purposes)
# * TA: Travel agents
# * TO: Tour operators
# ### **distribution_channel** (A distribution channel is a chain of businesses or intermediaries through which a good or service passes until it reaches the final buyer or the end consumer)
# * TA: Travel agents
# * TO: Tour operators
# ### **is_repeated_guest** (value indicating if the booking name was from repeated guest)
# * 1: Yes
# * 0: No
# ### **previous_cancellations**
# * Number of previous bookings that were cancelled by the customer prior to the current booking
# ### **previous_bookings_not_canceled**
# * Number of previous bookings not cancelled by the customer prior to the current booking
# ### **reserved_room_type**
# * Code of room type reserved. Code is presented instead of designation for anonymity reasons.
# ### **assigned_room_type**
# * Code for the type of room assigned to the booking. Sometimes the assigned room type differs from the reserved room type due to hotel operation * reasons (e.g. overbooking) or by customer request. Code is presented instead of designation for anonymity reasons.
# ### **booking_changes**
# * Number of changes/amendments made to the booking from the moment the booking was entered on the PMS until the moment of check-in or cancellation
# ### **deposit_type**
# * Indication on if the customer made a deposit to guarantee the booking. This variable can assume three categories: No Deposit – no deposit was made; Non Refund – a deposit was made in the value of the total stay cost; Refundable – a deposit was made with a value under the total cost of stay.
# ### **agent**
# * ID of the travel agency that made the booking
# ### **company**
# * ID of the company/entity that made the booking or responsible for paying the booking. ID is presented instead of designation for anonymity reasons
# ### **day_in_waiting_list**
# * Number of days the booking was in the waiting list before it was confirmed to the customer
# ### **customer_type**
# * Contract - when the booking has an allotment or other type of contract associated to it;
# * Group – when the booking is associated to a group;
# * Transient – when the booking is not part of a group or contract, and is not associated to other transient booking;
# * Transient-party – when the booking is transient, but is associated to at least other transient booking
# ### **adr** (average daily rate)
# * average daily rate =
#
# ### **required_car_parking_spaces**
# * Number of car parking spaces required by the customer
# ### **total_of_special_requests**
# * Number of special requests made by the customer (e.g. twin bed or high floor)
# ### **reservation_status**
# * Canceled – booking was canceled by the customer;
# * Check-Out – customer has checked in but already departed;
# * No-Show – customer did not check-in and did inform the hotel of the reason why
# ### **reservation_status_date**
# * Date at which the last status was set. This variable can be used in conjunction with the ReservationStatus to understand when was the booking canceled or when did the customer checked-out of the hotel

# %% [markdown]
# # Requairments

# %%
# Importing required packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading Dataset

# %%
# Read Dataset from CSV file
data = pd.read_csv(r'./Hotel Bookings.csv')
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# # **Questions**

# %% [markdown]
# ### 1.  There  are  two  types  of  hotels  in  the  dataset,  which  type  of  hotels booked most? Plot a pie chart to show the results.
# ### 2. What  percentage  of  bookings  were  cancelled?  What  type  of  chart do you suggest to show the results?
# ### 3. Based on different hotel types, what percentage of bookings were cancelled? What type of chart do you suggest to show the results?
# ### 4.  In  different  years,  what  type  of  hotels  were  booked  most  and booked least? Draw a proper countplot to show the results.
# ### 5. According  to  different  hotel  types,  how  ‘adr’  changes  in  different months?
# ### 6.  Check  hotel  wise  daily  rates  mean,  standard  deviation,  median, min and max.
# ### 7.  Extract  the  number  of  bookings  per  country  and  investigate  that most of the guests are from which countries?
# ### 8. According  to  the  ‘market_segment’  most  of  the  guests  book  their  rooms on what channels?

# %% [markdown]
# # **EDA section**

# %% [markdown]
# ## **Hotel Types Analysis**
# The dataset provides insights into hotel types, revealing the distribution of bookings between "City Hotel" and "Resort Hotel." The analysis indicates that there were a total of 119,390 hotel bookings, with "City Hotel" accounting for 66.5% (79,330 bookings) and "Resort Hotel" representing 33.5% (40,060 bookings) of the total.

# %%
# Extract Hotel Types and count them
hotel_types = data['hotel'].value_counts()
hotel_types
# Out:
# City Hotel      79330
# Resort Hotel    40060
# Name: hotel, dtype: int64

# %%
# Plot Values
fig, ax = plt.subplots(figsize=(8, 8))
colors = ['#643843', '#99627A']
explode = (0, 0.1)
ax.pie(hotel_types, labels=hotel_types.index, colors=colors, autopct='%1.1f%%'
       , startangle=90, explode=explode, labeldistance=0.4, textprops={'fontsize': 16, 'color': 'lightgray'});
ax.axis('equal');
ax.set_title('Hotel Types',  fontdict={'fontsize': 20, 'color': 'lightgray', 'fontweight': 'bold'
                                       , 'verticalalignment': 'bottom', 'horizontalalignment': 'center', 'backgroundcolor': '#643843'});
ax.legend(loc='upper left');
plt.show()

# %% [markdown]
# * The dominance of "City Hotel" bookings suggests a higher demand or popularity for urban accommodations.
# * "Resort Hotel" bookings, while comprising a smaller share, may attract a specific demographic seeking a more leisure-oriented stay.
# * Understanding the distribution helps in resource allocation, service optimization, and anticipating customer preferences.

# %% [markdown]
# # **Hotel Booking Cancellation Analysis**
# The dataset reveals crucial information about booking cancellations, highlighting the number of cancellations and non-cancellations. The analysis indicates that out of a total of 119,390 bookings:
#
# * ### Cancellations:
#
#      * The dataset records 75,166 cancellations, representing a significant portion of the bookings.
# * ### Non-Cancellations:
#
#      * Non-cancellations account for 44,224 bookings, indicating instances where guests proceeded with their original reservation plans.

# %%
# Count canceled and not_canceled rows
canceling = data['is_canceled'].value_counts()
canceling
# Out:
# 0    75166
# 1    44224
# Name: is_canceled, dtype: int64

# %%
# Plot the Values
fig, ax = plt.subplots(figsize=(8, 8))
colors = ['#643843', '#99627A']
explode = (0, 0.1)
ax.pie(canceling, labels=['Canceled', 'Not Canceled'], colors=colors, autopct='%1.1f%%'
       , startangle=90, explode=explode, labeldistance=0.4, textprops={'fontsize': 16, 'color': 'lightgray'});

ax.axis('equal');
ax.set_title('Canceling Status',  fontdict={'fontsize': 20, 'color': 'lightgray', 'fontweight': 'bold'
                                       , 'verticalalignment': 'bottom', 'horizontalalignment': 'center', 'backgroundcolor': '#643843'});
ax.legend(loc='upper left');
plt.show()

# %% [markdown]
# 1. **Cancellation Rate:**
#
#     * The high number of cancellations, constituting the majority, suggests a notable cancellation rate within the dataset.
# 2. **Operational Implications:**
#
#     * Hotel management should consider refining cancellation policies or implementing strategies to mitigate cancellations, such as offering flexible booking options or incentives for non-cancellation.
# 3. **Customer Behavior:**
#
#     * Understanding the reasons behind cancellations may provide valuable insights into customer preferences, external factors, or the need for enhanced communication.
# 4. **Revenue Considerations:**
#
#     * Analyzing cancellations is crucial for revenue forecasting and resource management, ensuring that operational capacities align with actual demand.
# 5. **Strategic Adjustments:**
#
#     * Hotel administrators can use this information to adapt marketing strategies, optimize room availability, and enhance customer satisfaction to reduce the likelihood of cancellations.
#
# In conclusion, this analysis of booking cancellations and non-cancellations provides a foundation for identifying patterns, refining operational strategies, and tailoring guest services to improve overall customer satisfaction and maximize revenue.

# %% [markdown]
# # **Hotel Booking Cancellation Analysis by Hotel Type**
# The analysis provides insights into booking cancellations based on different hotel types, specifically "City Hotel" and "Resort Hotel." The breakdown of bookings by cancellation status is as follows:
#
# * **City Hotel:**
#
#     * Not Canceled (is_canceled=0): 46,228 bookings
#     * Canceled (is_canceled=1): 33,102 bookings
# * **Resort Hotel:**
#
#     * Not Canceled (is_canceled=0): 28,938 bookings
#     * Canceled (is_canceled=1): 11,122 bookings

# %%
canceling_hotel_types = data.groupby('hotel')['is_canceled'].value_counts()
canceling_hotel_types
# Out:
# hotel         is_canceled
# City Hotel    0              46228
#               1              33102
# Resort Hotel  0              28938
#               1              11122
# Name: is_canceled, dtype: int64

# %%
# Extract relevant data for the pie chart
labels1 = ['City Hotel', 'Resort Hotel']
sizes_outer = data['hotel'].value_counts()
labels2  = ['Not Canceled', 'Canceled', 'Not Canceled', 'Canceled']
sizes_inner = data.groupby('hotel')['is_canceled'].value_counts()

# Create a color map for the outer and inner pie chart sections
outer_colors = ['#643843', '#99627A']
inner_colors = ['#B47B84', '#CAA6A6', '#B47B84', '#CAA6A6']

# Create the pie chart
fig, ax = plt.subplots(figsize=(8, 8))

size = 0.4

# Outer pie chart
ax.pie(sizes_outer, radius=1, labels=labels1, colors=outer_colors,
       wedgeprops=dict(width=size, edgecolor='w'), autopct='%1.1f%%', pctdistance=0.8
       , labeldistance=0.65, textprops={'fontsize': 16, 'color': 'lightgray'})

# Inner pie chart
ax.pie(sizes_inner, radius=1 - size, colors=inner_colors,
       wedgeprops=dict(width=size, edgecolor='w'), autopct=f'%1.1f%%\n{labels2[1]}', pctdistance=0.6
       , labeldistance=0.4, textprops={'fontsize': 14, 'color': '#3C3633'})

ax.axis('equal');

ax.set_title('Canceling Status',  fontdict={'fontsize': 20, 'color': 'lightgray', 'fontweight': 'bold'
                                       , 'verticalalignment': 'bottom', 'horizontalalignment': 'center', 'backgroundcolor': '#643843'});

plt.show()

# %% [markdown]
# ## **Key Findings:**
# 1. **Cancellation Distribution:**
#
#     * In the "City Hotel," the majority of bookings (58.3%) were not canceled, while 41.7% were canceled.
# For the "Resort Hotel," a higher percentage (72.2%) of bookings were not canceled, and 27.8% were canceled.
#
# 2. **Cancellation Rates by Hotel Type:**
#
#     * The cancellation rate is relatively higher for the "City Hotel" compared to the "Resort Hotel."
# Strategies to manage and reduce cancellations may need to be tailored based on the hotel type.
#
# 3. **Operational Considerations:**
#
#     * Hotel management should consider the implications of cancellation rates on overall operational efficiency and revenue.
#
# 4. **Customer Preferences:**
#
#     * Understanding the cancellation patterns for each hotel type can inform marketing and customer retention strategies.
#
# 5. **Future Strategies:**
#
#     * Continuous monitoring of cancellation trends and the effectiveness of implemented strategies is essential for ongoing improvement.
#
# This analysis provides a detailed breakdown of booking cancellations by hotel type, offering valuable insights for hotel management to adapt strategies and enhance the overall guest experience.

# %% [markdown]
# # **Hotel Booking Analysis by Year**
#
# In this analysis, we explore the booking trends for different types of hotels across multiple years.

# %%
data.groupby('arrival_date_year').agg({'hotel' : 'value_counts'}).unstack()
# Out:
#                        hotel
# hotel             City Hotel Resort Hotel
# arrival_date_year
# 2015                   13682         8314
# 2016                   38140        18567
# 2017                   27508        13179

# %%
year_count = data.groupby('arrival_date_year').agg({'hotel' : 'value_counts'}).unstack()

# %%
# Plotting the bar plot with sliced bins and showing percentages
fig, ax = plt.subplots(figsize=(10, 6))

year_count.plot(kind='bar', stacked=True, ax=ax)

# Adding percentage labels on top of each bar
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy()
    ax.annotate(f'{height}', (x + width / 2, y + height / 2), ha='center', va='center', fontsize=10, color='white')

ax.set_ylabel('Number of booking', loc='bottom')
ax.set_title('Hotel Booking by Year', loc='left', fontdict={'fontsize': 20, 'color': 'gray', 'fontweight': 'bold'});
ax.set_xlabel('Y ear',loc='left')
ax.spines[['top', 'right']].set_visible(False)
ax.legend()

plt.show()

# %% [markdown]
# ### Most Booked Hotel Types
#
# #### Year 2015
# - **City Hotel**: 13,682 bookings
# - **Resort Hotel**: 8,314 bookings
#
# #### Year 2016
# - **City Hotel**: 38,140 bookings
# - **Resort Hotel**: 18,567 bookings
#
# #### Year 2017
# - **City Hotel**: 27,508 bookings
# - **Resort Hotel**: 13,179 bookings
#
# ### Least Booked Hotel Types
#
# *Note: The provided information focuses on the most and least booked hotel types, and intermediate years are not included in this summary.*
#
# ### Conclusion
#
# The analysis provides insights into the popularity of different hotel types across the years. City Hotels appear to be consistently booked more than Resort Hotels, with the highest disparity observed in the year 2016.

# %% [markdown]
# # **Monthly ADR Variation Across Different Hotel Types**
# The analysis explores how the Average Daily Rate (ADR) varies for different hotel types across different months. The results provide insights into the pricing dynamics in the hotel industry.

# %%
city_hotel = data[['hotel','arrival_date_month', 'adr']][data['hotel'] == 'City Hotel']
resort_hotel = data[['hotel','arrival_date_month', 'adr']][data['hotel'] == 'Resort Hotel']
city_adr = city_hotel[['arrival_date_month', 'adr']].groupby('arrival_date_month', as_index=False).mean().sort_values(by='adr')
resort_adr = resort_hotel[['arrival_date_month', 'adr']].groupby('arrival_date_month', as_index=False).mean().sort_values(by='adr')
city_adr
# Out:
#    arrival_date_month         adr
# 4             January   82.628986
# 3            February   85.088278
# 9            November   88.069601
# 2            December   88.826307
# 7               March   92.643116
# 10            October   99.974498
# 11          September  110.004661
# 5                July  110.734292
# 0               April  111.251838
# 1              August  114.680455
# 6                June  119.074341
# 8                 May  121.638560

# %%
fig, ax = plt.subplots(figsize=(14, 8))

# Set the width of the bars
bar_width = 0.35

# Calculate the positions for the bars
resort_positions = np.arange(len(resort_adr['arrival_date_month']));
city_positions = resort_positions + bar_width

# Plot the bars side by side
plt.bar(resort_positions, resort_adr['adr'], width=bar_width, color='#643843', label='Resort ADR');
plt.bar(city_positions, city_adr['adr'], width=bar_width, color='#99627A', label='City ADR');
# Customize the plot
plt.xlabel('Month', loc='left');
plt.ylabel('ADR', loc='bottom');
plt.title('ADR Comparison', loc='left', fontdict={'fontsize': 20, 'color': 'gray', 'fontweight': 'bold'});
plt.xticks(city_positions - bar_width / 2, resort_adr['arrival_date_month']);  # Set x-axis labels at the center of the grouped bars
ax.spines[['top', 'right']].set_visible(False)
plt.legend();

# %% [markdown]
# ## Observations:
# 1. **April and May:** Both City and Resort hotels show a significant increase in ADR during April and May, reaching values of 111.25 and 121.64, respectively.
#
# 2. **June to September:** The ADR continues to rise steadily from June to September, indicating a peak season for both hotel types.
#
# 3. **October and November:** October and November see a slight decrease in ADR, potentially due to the transition from peak to off-peak seasons.
#
# 4. **December to February:** ADR experiences a dip in December, followed by a gradual increase in January and February.
#
# 5. **March:** March shows a notable increase in ADR, signaling a rise in demand.
#
# These findings provide valuable insights for hotel management, allowing them to strategically adjust pricing strategies based on seasonal variations and customer demand. The analysis helps optimize revenue and enhance overall business performance.

# %% [markdown]
# ## **Hotel-wise Daily Rates Statistics**
#
# **Mean:** Average daily rate
# **Std:** Standard deviation of daily rates
# **Median:** Median daily rate
# **Min:** Minimum daily rate
# **Max:** Maximum daily rate

# %%
data[['hotel' , 'adr']].groupby('hotel').agg({'adr' : ['mean' , 'std', 'median', 'min', 'max'] })
# Out:
#                      adr
#                     mean        std median   min     max
# hotel
# City Hotel    105.304465  43.602954   99.9  0.00  5400.0
# Resort Hotel   94.952930  61.442418   75.0 -6.38   508.0

# %% [markdown]
# | Hotel       | Mean   | Std    | Median | Min   | Max   |
# |-------------|--------|--------|--------|-------|-------|
# | City Hotel  | 105.30 | 43.60  | 99.9   | 0.00  | 5400.0|
# | Resort Hotel| 94.95  | 61.44  | 75.0   | -6.38 | 508.0 |

# %% [markdown]
# ## **Analysis: Number of Bookings per Country**
#
# This analysis provides insights into the distribution of hotel bookings across different countries. The table displays the number of bookings for each country code, with Portugal (PRT) leading as the country with the highest number of bookings, followed by the United Kingdom (GBR) and France (FRA). The dataset reflects the diverse origins of guests, with various countries contributing to the overall bookings. Understanding the geographic distribution can be valuable for hotel management to tailor services and marketing strategies to cater to the preferences and needs of guests from different regions.

# %%
data['country'].value_counts()
# Out:
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
#        ...
# DJI        1
# BWA        1
# HND        1
# VGB        1
# NAM        1
# Name: country, Length: 177, dtype: int64

# %%
most_of_guests = data[data['reservation_status'] == 'Check-Out']['country'].value_counts().head(10).sort_values()

# %%
fig, ax =plt.subplots(figsize=(12,6))

plt.barh(most_of_guests.index, most_of_guests.values, color='#99627A');

for i, v in enumerate(most_of_guests.values):
    plt.text(v + 3, i, str(v), color='gray', fontdict={'fontsize': 12});

plt.xlabel('Reservation', loc='left', fontdict={'fontsize': 14});
plt.ylabel('Country', loc='bottom',  fontdict={'fontsize': 14});
plt.title('Number Of Reservation in each Country', loc='left', fontdict={'fontsize': 20, 'color': 'gray', 'fontweight': 'bold'});
ax.spines[['top', 'right']].set_visible(False)

# %% [markdown]
# ## Analysis: Preferred Booking Channels by Market Segment
#
# This analysis delves into the booking channels preferred by guests based on the 'market_segment' attribute. The table illustrates that the 'Online TA' (Travel Agents) channel is the most popular, with a substantial number of guests choosing this online booking platform. Following closely are 'Offline TA/TO' (Travel Agents/Tour Operators), 'Groups,' and 'Direct' bookings, showcasing the diversity of channels through which guests reserve their rooms. Understanding these preferences is crucial for hotel management to optimize marketing efforts and enhance the guest booking experience.

# %%
most_booking_channels = data['market_segment'].value_counts().sort_values()
most_booking_channels
# Out:
# Undefined            2
# Aviation           237
# Complementary      743
# Corporate         5295
# Direct           12606
# Groups           19811
# Offline TA/TO    24219
# Online TA        56477
# Name: market_segment, dtype: int64

# %%
fig, ax =plt.subplots(figsize=(12,6))

plt.barh(most_booking_channels.index, most_booking_channels.values, color='#99627A');

for i, v in enumerate(most_booking_channels.values):
    plt.text(v + 3, i, str(v), color='gray', fontdict={'fontsize': 12});

plt.xlabel('Number of Bookings', loc='left', fontdict={'fontsize': 14});
plt.ylabel('Booking Channels', loc='bottom',  fontdict={'fontsize': 14});
plt.title('Preferred Booking Channels by Market Segment', loc='left', fontdict={'fontsize': 20, 'color': 'gray', 'fontweight': 'bold'});
ax.spines[['top', 'right']].set_visible(False)

# %% [markdown]
# ## **Overview of arrival period**

# %%
lst3 = ['hotel', 'arrival_date_year', 'arrival_date_month','arrival_date_day_of_month' ]
period_arrival = data[lst3]
sns.countplot(data = period_arrival, x = 'arrival_date_year', hue = 'hotel')
# Out:
# <Axes: xlabel='arrival_date_year', ylabel='count'>

# %%
plt.figure(figsize=(20,5))

sns.countplot(data = period_arrival, x = 'arrival_date_month', hue = 'hotel', order = ['January', 'February', 'March', 'April', 'May', 'June', 'July',
          'August', 'September', 'October', 'November', 'December']).set_title('Graph showing number of arrival per month',fontsize=20)
plt.xlabel('Month')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize=(15,5))

sns.countplot(data = period_arrival, x = 'arrival_date_day_of_month', hue = 'hotel').set_title('Graph showing number of arrival per day', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Graph showing number of arrival per day')
